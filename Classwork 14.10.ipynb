# %%
Class Car:
    def __init__(self,car_name,colour,size,power,weight,acceleration,control,price,location,condition,cleanliness,fuel):
        self.name = name
        self.car_name=car_name
        self.colour=colour
        self.size=size
        self.power=power
        self.weight=weight
        self.acceleration=acceleration
        self.control=control
        self.price=price
        self.location=location
        self.condition=condition
        self.cleanliness=cleanliness
        self.fuel=fuel
    def _name_change_(self,car_name):
        print(self.car_name)
    def _engine_change_(self,power,weight,control,price,fuel):
        pass
    def _location_reach(self,power,weight,acceleration,control,location,fuel):
        pass
    def _break_(self,condition,price):
        pass
    def _repair_(self,condition,price):
        pass
    def _car_information_(self,car_name,colour,size,power,weight,acceleration,control,price,location,condition,cleanliness,fuel):
        print(self.car_name)
        print(self.colour,self.size,self.power,self.weight,self.acceleration)
        print(self.control,self.price,self.location)
        print(self.condition,self.cleanliness,self.fuel)
    

Class Location:
    
    def __init__(self,coordinates,location_name,type_of_location,traffic_jam,weather,petrol_station):
        
    def _distance_(self,coordinates,location_name,type_of_location,traffic_jam,weather):
        pass
    def _weather_change_(self,coordinates,weather):
        pass
    def _location_information_(self,coordinates,location_name,type_of_location,traffic_jam,weather,petrol_station):
        print(self.coordinates)
        print(self.location_name,self.type_of_location)
        print(self.traffic_jam,self.weather,self.petrol_station)
    

Class Human:
    def __init__(human_name,human_age,amount_of_cars,driving_experience,amount_of_money):
        pass
    def _clean_the_car_(self):
        pass
    def _repair_the_car_(self):
        pass
    def _buy_a_car_(self,amount_of_money):
        pass
    def _ride_a_car_(self,huma_age,amount_of_cars,driving_experience):
        pass
    def _traffic_accident_(self,amount_of_cars,driving_experience):
        pass
    def _petrol_the_car_(self,amount_of_cars,amount_of_money):
        pass
    def _human_information_(self,human_name,human_age,amount_of_cars,driving_experience,amount_of_money):
        pass
